# %% [markdown]
# <a href="https://colab.research.google.com/github/Wikanes-k/Project_LenLen/blob/main/missing%E0%B8%A5%E0%B8%AD%E0%B8%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ส่วนของการ Import
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/Work/Project + สหกิจ' #กำหนด path ของโฟลเดอร์ที่ Data อยู่
# Out:
# Mounted at /content/drive

# %%
data_OH = pd.read_csv(os.path.join(path,'missing.csv'))  
data_OH
# Out:
#              Date     id    imp  click
# 0       1/12/2022     41   59.0      2
# 1       2/12/2022     41   49.0      8
# 2       3/12/2022     41   43.0     11
# 3       4/12/2022     41   84.0     17
# 4       5/12/2022     41   58.0      2
# ...           ...    ...    ...    ...
# 12984  27/12/2022  34513  178.0      8
# 12985  28/12/2022  34513  160.0      5
# 12986  29/12/2022  34513   46.0      0
# 12987  30/12/2022  34513   34.0      6
# 12988  31/12/2022  34513   13.0      2
#
# [12989 rows x 4 columns]

# %%
data_OH.isnull().any()
# Out:
# Date     False
# id       False
# imp       True
# click    False
# dtype: bool

# %% [markdown]
# ##quadratic

# %%
quadratic = data_OH.interpolate(method = 'quadratic')

# %%
quadratic
# Out:
#              Date     id    imp  click
# 0       1/12/2022     41   59.0      2
# 1       2/12/2022     41   49.0      8
# 2       3/12/2022     41   43.0     11
# 3       4/12/2022     41   84.0     17
# 4       5/12/2022     41   58.0      2
# ...           ...    ...    ...    ...
# 12984  27/12/2022  34513  178.0      8
# 12985  28/12/2022  34513  160.0      5
# 12986  29/12/2022  34513   46.0      0
# 12987  30/12/2022  34513   34.0      6
# 12988  31/12/2022  34513   13.0      2
#
# [12989 rows x 4 columns]

# %%
linear = data_OH.interpolate(method = 'linear')
linear
# Out:
#              Date     id    imp  click
# 0       1/12/2022     41   59.0      2
# 1       2/12/2022     41   49.0      8
# 2       3/12/2022     41   43.0     11
# 3       4/12/2022     41   84.0     17
# 4       5/12/2022     41   58.0      2
# ...           ...    ...    ...    ...
# 12984  27/12/2022  34513  178.0      8
# 12985  28/12/2022  34513  160.0      5
# 12986  29/12/2022  34513   46.0      0
# 12987  30/12/2022  34513   34.0      6
# 12988  31/12/2022  34513   13.0      2
#
# [12989 rows x 4 columns]

# %% [markdown]
# ##KNN

# %%
from sklearn.impute import KNNImputer
import pandas as pd

# %%
target = data_OH['imp']
features = data_OH.drop('imp', axis=1)

# %%
imputer = KNNImputer(n_neighbors=3)

# %%
imputed_features = imputer.fit_transform(features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-9215fefb750b> in <module>
# ----> 1 imputed_features = imputer.fit_transform(features)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
# ...
