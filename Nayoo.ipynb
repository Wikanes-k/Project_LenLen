# %% [markdown]
# <a href="https://colab.research.google.com/github/Wikanes-k/Project_LenLen/blob/main/Nayoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ส่วนของการ Import
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/Work/สหกิจน่าอยู่/2.งาน one hand' #กำหนด path ของโฟลเดอร์ที่ Data อยู่
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##one-hand

# %%
data_OH = pd.read_csv(os.path.join(path,'one-hand.csv'))  
data_OH
# Out:
#          id     type post_type listing_type  parent_id  draft_for  \
# 0        41  project       new         sale        NaN        NaN
# 1        42  project       new         sale        NaN        NaN
# 2        43  project       new         sale        NaN        NaN
# 3        44  project       new         sale        NaN        NaN
# 4        45  project       new         sale        NaN        NaN
# ...     ...      ...       ...          ...        ...        ...
# 2232  33461  project       new         sale        NaN        NaN
# 2233  33463  project       new         sale        NaN        NaN
# 2234  33475  project       new         sale        NaN        NaN
# 2235  33481  project       new         sale        NaN        NaN
# 2236  33537  project       new         sale        NaN        NaN
#
#       project_name  province_id  district_id  sub_district_id  ...  \
# 0              NaN            6        121.0            708.0  ...
# ...

# %%
data_OH1 = data_OH[['id','parent_id','province_id','zone_id','property_type_id','user_id','name_th','latitude','longitude','quality_calculate_date','starting_price','ending_price','model','sell_price','created_at','updated_at']] #เลือกคอลัมน์ที่ต้องการ
data_OH1 #แสดงตาราง
# Out:
#          id  parent_id  province_id  zone_id  property_type_id  user_id  \
# 0        41        NaN            6      5.0               1.0       19
# 1        42        NaN            6      2.0               1.0       19
# 2        43        NaN            6      6.0               1.0       19
# 3        44        NaN            6      6.0               8.0       19
# 4        45        NaN            6      1.0               8.0       19
# ...     ...        ...          ...      ...               ...      ...
# 2232  33461        NaN            9    100.0               1.0    10458
# 2233  33463        NaN           43    144.0               1.0    10265
# 2234  33475        NaN            9    100.0               1.0    10458
# 2235  33481        NaN           43    144.0               1.0    10261
# 2236  33537        NaN            9    110.0               1.0     9036
#
#                      name_th   latitude   longitude quality_calculate_date  \
# ...

# %%
#data_OH2  = data_OH1[province_id('6')] #เลือกเฉพาะข้อมูลในปี 2020 โดยใช้คำสั่ง .announce_date
#data_OH2
